# %%
# !pip install azure-storage-blob
# !pip install pyarrow
# !pip install psycopg2 sqlalchemy
# Out:
# Collecting azure-storage-blob
#   Downloading azure_storage_blob-12.19.1-py3-none-any.whl (394 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.5/394.5 kB 3.3 MB/s eta 0:00:00
# Collecting azure-core<2.0.0,>=1.28.0 (from azure-storage-blob)
#   Downloading azure_core-1.30.1-py3-none-any.whl (193 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.4/193.4 kB 18.5 MB/s eta 0:00:00
# Requirement already satisfied: cryptography>=2.1.4 in /usr/local/lib/python3.10/dist-packages (from azure-storage-blob) (42.0.5)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from azure-storage-blob) (4.11.0)
# Collecting isodate>=0.6.1 (from azure-storage-blob)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from azure-core<2.0.0,>=1.28.0->azure-storage-blob) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from azure-core<2.0.0,>=1.28.0->azure-storage-blob) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=2.1.4->azure-storage-blob) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (2024.2.2)
# Installing collected packages: isodate, azure-core, azure-storage-blob
# Successfully installed azure-core-1.30.1 azure-storage-blob-12.19.1 isodate-0.6.1
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.10/dist-packages (14.0.2)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.10/dist-packages (from pyarrow) (1.25.2)
# Requirement already satisfied: psycopg2 in /usr/local/lib/python3.10/dist-packages (2.9.9)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.10/dist-packages (2.0.29)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy) (3.0.3)

# %%
import pandas as pd
import numpy as np
import json
import requests
from io import StringIO
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient
from math import ceil
import datetime
import calendar
from sqlalchemy import create_engine
import psycopg2
from datetime import datetime

# %%
def azure_upload_blob(connect_str, container_name, blob_name, data):
    blob_service_client = BlobServiceClient.from_connection_string(connect_str)
    blob_client = blob_service_client.get_blob_client(container=container_name, blob=blob_name)
    blob_client.upload_blob(data, overwrite=True)
    print(f"Uploaded to Azure Blob: {blob_name}")

def azure_download_blob(connect_str, container_name, blob_name):
    blob_service_client = BlobServiceClient.from_connection_string(connect_str)
    blob_client = blob_service_client.get_blob_client(container=container_name, blob=blob_name)
    download_stream = blob_client.download_blob()
    return download_stream.readall()

# %%
def week_of_month(dt):
    first_day = dt.replace(day=1)
    dom = dt.day
    adjusted_dom = dom + first_day.weekday()
    return int(adjusted_dom/7.0)

def get_week_of_year(date_str):
    """
    Calculate the ISO week number of the year for a given date.

    Parameters:
    date_str (str): A date string in the format 'YYYY-MM-DD'.

    Returns:
    int: The ISO week number of the year.
    """
    #parse the input string to a datetime object
    date = datetime.strptime(date_str, '%Y-%m-%d')

    #get the ISO calendar week number
    week_of_year = date.isocalendar()[1]

    return week_of_year

# %%
#specify the path to your JSON configuration file
config_file_path = 'config.json'

#load with JSON configuration file
with open(config_file_path, 'r') as config_file:
    config = json.load(config_file)

CONNECTION_STRING_AZURE_STORAGE = config["connectionString"]
CONTAINER_AZURE = 'bic'

#initialize the blobserviceclient
blob_service_client = BlobServiceClient.from_connection_string(CONNECTION_STRING_AZURE_STORAGE)

#get the container client
container_client = blob_service_client.get_container_client(CONTAINER_AZURE)

bic_df = pd.DataFrame()

#list all blobs in specified container
blob_list = container_client.list_blobs()
for blob in blob_list:
  print(blob.name)
  blob_client = container_client.get_blob_client(blob=blob.name)
  blob_data = blob_client.download_blob()
  blob_content = blob_data.readall().decode('utf-8')
  df = pd.read_csv(StringIO(blob_content))
  #display the head of the dataframe
  print(df.shape)
  bic_df = df.copy()
# Out:
# bic.csv
# (10000, 31)
# bic_20240503.csv
# (10000, 31)

# %%
bic_df.head()
# Out:
#   violation_number  bic_number                         account_name  \
# 0       TWC-210067       269.0              JOE'S WASTE PAPER CORP.
# 1       TWC-223791         NaN  ROCK E SMALL PLUMBING & HEATING INC
# 2       TWC-222099         NaN           SCLAFMORE CONSTRUCTION LLC
# 3       TWC-226916      1240.0            ROYAL WASTE SERVICES INC.
# 4       TWC-227078         NaN                  Izzy Landscaper Inc
#
#   type_of_violation violation_phase violation_disposition account_type  \
# 0              OATH          Issued               Settled      License
# 1              OATH          Issued               Settled   Unlicensed
# 2              OATH          Issued               Settled   Unlicensed
# 3              OATH          Issued               Settled      License
# 4              OATH          Issued               Settled   Unlicensed
#
#   violation_account_address violation_account_city violation_account_state  \
# 0           P.O. BOX 320358               BROOKLYN                      NY
# 1      152-32 Rockaway Blvd                Jamaica                      NY
# 2         69-37 50th Avenue                 Queens                      NY
# 3     168-46 DOUGLAS AVENUE                JAMAICA                      NY
# 4     110 Brightside Avenue          Central Islip                      NY
#
#    ...                                description_of_rule export_date  \
# 0  ...  Failed to timely disclose to Commission employ...  2024-05-03
# 1  ...  Removed collected or disposed of trade waste o...  2024-05-03
# 2  ...  Removed collected or disposed of trade waste o...  2024-05-03
# 3  ...  A trade waste vehicle must not be operated unl...  2024-05-03
# 4  ...  It shall be unlawful for any person to remove,...  2024-05-03
#
#     latitude  longitude  community_board  council_district census_tract  \
# 0        NaN        NaN              NaN               NaN          NaN
# 1  40.671873 -73.784991             12.0              28.0        294.0
# 2  40.736912 -73.894918              2.0              30.0        489.0
# 3  40.703949 -73.789576             12.0              27.0        444.0
# 4        NaN        NaN              NaN               NaN          NaN
#
#          bin           bbl                        nta
# 0        NaN           NaN                        NaN
# 1  4263107.0  4.121250e+09  Springfield Gardens North
# 2  4056355.0  4.024350e+09           Elmhurst-Maspeth
# 3        NaN           NaN                    Jamaica
# 4        NaN           NaN                        NaN
#
# [5 rows x 31 columns]

# %%
#cleaning
bic_df['bic_number'] = bic_df['bic_number'].astype('Int64')
bic_df['community_board'] = bic_df['community_board'].astype('Int64')
bic_df['census_tract'] = bic_df['census_tract'].astype('Int64')
bic_df['bin'] = bic_df['bin'].astype('Int64')
bic_df['bbl'] = bic_df['bbl'].astype('Int64')

bic_df.head()
# Out:
#   violation_number  bic_number                         account_name  \
# 0       TWC-210067         269              JOE'S WASTE PAPER CORP.
# 1       TWC-223791        <NA>  ROCK E SMALL PLUMBING & HEATING INC
# 2       TWC-222099        <NA>           SCLAFMORE CONSTRUCTION LLC
# 3       TWC-226916        1240            ROYAL WASTE SERVICES INC.
# 4       TWC-227078        <NA>                  Izzy Landscaper Inc
#
#   type_of_violation violation_phase violation_disposition account_type  \
# 0              OATH          Issued               Settled      License
# 1              OATH          Issued               Settled   Unlicensed
# 2              OATH          Issued               Settled   Unlicensed
# 3              OATH          Issued               Settled      License
# 4              OATH          Issued               Settled   Unlicensed
#
#   violation_account_address violation_account_city violation_account_state  \
# 0           P.O. BOX 320358               BROOKLYN                      NY
# 1      152-32 Rockaway Blvd                Jamaica                      NY
# 2         69-37 50th Avenue                 Queens                      NY
# 3     168-46 DOUGLAS AVENUE                JAMAICA                      NY
# 4     110 Brightside Avenue          Central Islip                      NY
#
#    ...                                description_of_rule export_date  \
# 0  ...  Failed to timely disclose to Commission employ...  2024-05-03
# 1  ...  Removed collected or disposed of trade waste o...  2024-05-03
# 2  ...  Removed collected or disposed of trade waste o...  2024-05-03
# 3  ...  A trade waste vehicle must not be operated unl...  2024-05-03
# 4  ...  It shall be unlawful for any person to remove,...  2024-05-03
#
#     latitude  longitude  community_board  council_district census_tract  \
# 0        NaN        NaN             <NA>               NaN         <NA>
# 1  40.671873 -73.784991               12              28.0          294
# 2  40.736912 -73.894918                2              30.0          489
# 3  40.703949 -73.789576               12              27.0          444
# 4        NaN        NaN             <NA>               NaN         <NA>
#
#        bin         bbl                        nta
# 0     <NA>        <NA>                        NaN
# 1  4263107  4121250032  Springfield Gardens North
# 2  4056355  4024350036           Elmhurst-Maspeth
# 3     <NA>        <NA>                    Jamaica
# 4     <NA>        <NA>                        NaN
#
# [5 rows x 31 columns]

# %%
print(bic_df.columns)
# Out:
# Index(['violation_number', 'bic_number', 'account_name', 'type_of_violation',
#        'violation_phase', 'violation_disposition', 'account_type',
#        'violation_account_address', 'violation_account_city',
#        'violation_account_state', 'violation_account_postcode',
#        'borough_of_violation', 'date_of_violation', 'date_violation_issued',
#        'maximum_fine', 'fine_amount', 'date_fine_paid',
#        'early_settlement_violation', 'settlement_date', 'rule_code',
#        'number_of_counts', 'description_of_rule', 'export_date', 'latitude',
#        'longitude', 'community_board', 'council_district', 'census_tract',
#        'bin', 'bbl', 'nta'],
#       dtype='object')

# %%
# create  violation dimension

dim_violation = pd.DataFrame({
    'violation_id': range(1, len(bic_df) + 1),
    'violation_number': bic_df['violation_number'],
    'type_violation': bic_df['type_of_violation'],
    'violation_phase': bic_df['violation_phase']
})

dim_violation.head()
# Out:
#    violation_id violation_number type_violation violation_phase
# 0             1       TWC-210067           OATH          Issued
# 1             2       TWC-223791           OATH          Issued
# 2             3       TWC-222099           OATH          Issued
# 3             4       TWC-226916           OATH          Issued
# 4             5       TWC-227078           OATH          Issued

# %%
# create account dimension

dim_account = pd.DataFrame({
    'account_id': range(1, len(bic_df) + 1),
    'BIC_number': bic_df['bic_number'],
    'account_name': bic_df['account_name'],
    'account_type': bic_df['account_type']
})

dim_account.head()
# Out:
#    account_id  BIC_number                         account_name account_type
# 0           1         269              JOE'S WASTE PAPER CORP.      License
# 1           2        <NA>  ROCK E SMALL PLUMBING & HEATING INC   Unlicensed
# 2           3        <NA>           SCLAFMORE CONSTRUCTION LLC   Unlicensed
# 3           4        1240            ROYAL WASTE SERVICES INC.      License
# 4           5        <NA>                  Izzy Landscaper Inc   Unlicensed

# %%
# create location dimension

dim_location = pd.DataFrame({
    'location_id': range(1, len(bic_df) + 1),
    'borough': bic_df['borough_of_violation'],
    'Latitude': bic_df['latitude'],
    'Longitude': bic_df['longitude']
})

dim_location.head()
# Out:
#    location_id    borough   Latitude  Longitude
# 0            1  Manhattan        NaN        NaN
# 1            2   Brooklyn  40.671873 -73.784991
# 2            3   Brooklyn  40.736912 -73.894918
# 3            4      Bronx  40.703949 -73.789576
# 4            5     Queens        NaN        NaN

# %%
# create date dimension

bic_df['date_of_violation'] = pd.to_datetime(bic_df['date_of_violation'])


dim_date = pd.DataFrame({
    'date_id': np.arange(1, len(bic_df) + 1),
    'Date_original': bic_df['date_of_violation'],
    'date_Iso': bic_df['date_of_violation'].dt.date,
    'year': bic_df['date_of_violation'].dt.year,
    'quarter': bic_df['date_of_violation'].dt.quarter,
    'month': bic_df['date_of_violation'].dt.month,
    'month_name': bic_df['date_of_violation'].dt.strftime('%B'),
    'week_of_month': bic_df['date_of_violation'].apply(lambda x: (x.day - 1) // 7 + 1),
    'week_of_year': bic_df['date_of_violation'].dt.isocalendar().week,
    'day_number': bic_df['date_of_violation'].dt.day,
    'day_of_week': bic_df['date_of_violation'].dt.weekday + 1,
    'day_name': bic_df['date_of_violation'].dt.strftime('%A')
})



print(dim_date.head())
# Out:
#    date_id       Date_original    date_Iso  year  quarter  month month_name  \
# 0        1 2014-06-25 04:00:00  2014-06-25  2014        2      6       June
# 1        2 2014-06-25 04:00:00  2014-06-25  2014        2      6       June
# 2        3 2014-06-25 04:00:00  2014-06-25  2014        2      6       June
# 3        4 2014-06-25 04:00:00  2014-06-25  2014        2      6       June
# 4        5 2014-06-25 04:00:00  2014-06-25  2014        2      6       June
#
#    week_of_month  week_of_year  day_number  day_of_week   day_name
# 0              4            26          25            3  Wednesday
# 1              4            26          25            3  Wednesday
# 2              4            26          25            3  Wednesday
# 3              4            26          25            3  Wednesday
# 4              4            26          25            3  Wednesday

# %%
print(bic_df.columns)
# Out:
# Index(['violation_number', 'bic_number', 'account_name', 'type_of_violation',
#        'violation_phase', 'violation_disposition', 'account_type',
#        'violation_account_address', 'violation_account_city',
#        'violation_account_state', 'violation_account_postcode',
#        'borough_of_violation', 'date_of_violation', 'date_violation_issued',
#        'maximum_fine', 'fine_amount', 'date_fine_paid',
#        'early_settlement_violation', 'settlement_date', 'rule_code',
#        'number_of_counts', 'description_of_rule', 'export_date', 'latitude',
#        'longitude', 'community_board', 'council_district', 'census_tract',
#        'bin', 'bbl', 'nta', 'fact_id'],
#       dtype='object')

# %%
bic_df['fact_id'] = np.arange(1, len(bic_df) + 1)

new_order = ['fact_id', 'date_id', 'location_id', 'violation_id', 'account_id', 'fine_amount', 'maximum_fine']

bic_df = bic_df[new_order]


bic_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-82-cbc9b18483d5> in <cell line: 5>()
#       3 new_order = ['fact_id', 'date_id', 'location_id', 'violation_id', 'account_id', 'fine_amount', 'maximum_fine']
#       4
# ----> 5 bic_df = bic_df[new_order]
#       6
#       7
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3765             if is_iterator(key):
#    3766                 key = list(key)
# -> 3767             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3768
#    3769         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    5875             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5876
# -> 5877         self._raise_if_missing(keyarr, indexer, axis_name)
#    5878
#    5879         keyarr = self.take(indexer)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    5939
#    5940             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5941             raise KeyError(f"{not_found} not in index")
#    5942
#    5943     @overload
#
# KeyError: "['date_id', 'location_id', 'violation_id', 'account_id'] not in index"

# %%
#

database_url = 'postgresql:\\database:Azure1@@@cis44dw.postgres.database.azure.com/postgres'
engine = create_engine(database_url)
# Out:
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# <ipython-input-5-125005c81715> in <cell line: 4>()
#       2
#       3 database_url = 'postgresql:\\database:Azure1@@@cis44dw.postgres.database.azure.com/postgres'
# ----> 4 engine = create_engine(database_url)
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/create.py in create_engine(url, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/util/deprecations.py in warned(fn, *args, **kwargs)
#     279                         stacklevel=3,
#     280                     )
# --> 281             return fn(*args, **kwargs)  # type: ignore[no-any-return]
#     282
#     283         doc = fn.__doc__ is not None and fn.__doc__ or ""
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/create.py in create_engine(url, **kwargs)
#     544
#     545     # create url.URL object
# --> 546     u = _url.make_url(url)
#     547
#     548     u, plugins, kwargs = u._instantiate_plugins(kwargs)
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/url.py in make_url(name_or_url)
#     840
#     841     if isinstance(name_or_url, str):
# --> 842         return _parse_url(name_or_url)
#     843     elif not isinstance(name_or_url, URL) and not hasattr(
#     844         name_or_url, "_sqla_is_testing_if_this_is_a_mock_object"
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/url.py in _parse_url(name)
#     906
#     907     else:
# --> 908         raise exc.ArgumentError(
#     909             "Could not parse SQLAlchemy URL from string '%s'" % name
#     910         )
#
# ArgumentError: Could not parse SQLAlchemy URL from string 'postgresql:\database:Azure1@@@cis44dw.postgres.database.azure.com/postgres'

# %%
columnstoDrop = ['borough_of_violation', 'latitude', 'longitude']
bic_df.drop(columns = columnstoDrop, inplace = True)
bic_df.head()
# Out:
#   violation_number  bic_number                         account_name  \
# 0       TWC-210067       269.0              JOE'S WASTE PAPER CORP.
# 1       TWC-223791         NaN  ROCK E SMALL PLUMBING & HEATING INC
# 2       TWC-222099         NaN           SCLAFMORE CONSTRUCTION LLC
# 3       TWC-226916      1240.0            ROYAL WASTE SERVICES INC.
# 4       TWC-227078         NaN                  Izzy Landscaper Inc
#
#   type_of_violation violation_phase violation_disposition account_type  \
# 0              OATH          Issued               Settled      License
# 1              OATH          Issued               Settled   Unlicensed
# 2              OATH          Issued               Settled   Unlicensed
# 3              OATH          Issued               Settled      License
# 4              OATH          Issued               Settled   Unlicensed
#
#   violation_account_address violation_account_city violation_account_state  \
# 0           P.O. BOX 320358               BROOKLYN                      NY
# 1      152-32 Rockaway Blvd                Jamaica                      NY
# 2         69-37 50th Avenue                 Queens                      NY
# 3     168-46 DOUGLAS AVENUE                JAMAICA                      NY
# 4     110 Brightside Avenue          Central Islip                      NY
#
#    ...         rule_code number_of_counts  \
# 0  ...      17 RCNY 5-07                1
# 1  ...  NYC AC 16-505(a)                1
# 2  ...  NYC AC 16-505(a)                1
# 3  ...  17 RCNY  5-10(f)                1
# 4  ...  NYC AC 16-505(b)                1
#
#                                  description_of_rule  export_date  \
# 0  Failed to timely disclose to Commission employ...   2024-05-03
# 1  Removed collected or disposed of trade waste o...   2024-05-03
# 2  Removed collected or disposed of trade waste o...   2024-05-03
# 3  A trade waste vehicle must not be operated unl...   2024-05-03
# 4  It shall be unlawful for any person to remove,...   2024-05-03
#
#    community_board council_district  census_tract        bin           bbl  \
# 0              NaN              NaN           NaN        NaN           NaN
# 1             12.0             28.0         294.0  4263107.0  4.121250e+09
# 2              2.0             30.0         489.0  4056355.0  4.024350e+09
# 3             12.0             27.0         444.0        NaN           NaN
# 4              NaN              NaN           NaN        NaN           NaN
#
#                          nta
# 0                        NaN
# 1  Springfield Gardens North
# 2           Elmhurst-Maspeth
# 3                    Jamaica
# 4                        NaN
#
# [5 rows x 28 columns]
